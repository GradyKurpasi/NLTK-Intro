# %%
import nltk

# %%
nltk.download()
# This will popup (or likely pop-behind) a download script.  Shell will not return until that dialog is closed
print("Done")
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Done

# %%
from nltk.book import *
# You can refer to the texts below as text1, text2, etc.

# %%
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance("monstrous")
# Showing 11 instances of the word 'monstrous' from Moby Dick with surrounding word environment
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])
# Showing where the words "citizens", "democracy", "freedom", "duties", "America" occur in Innaugral Addresses 
# (Word 0 = start)

# %%
# Every unique word in The Book of Genesis
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
#Some stats on the book of Genesis
print(len(text3), " : # of words in the book of Genesis")
print(len(set(text3)), " : # of unique words in the book of Genesis")
# Out:
# 44764  : # of words in the book of Genesis
# 2789  : # of unique words in the book of Genesis

# %%
print(text3.count("smote"), " : # of occurences of  \"smote\" in Genesis")
# Out:
# 5  : # of occurences of  "smote" in Genesis

# %%
print(len(text1), " : # of words in Moby Dick")
print(len(set(text1)), " : # of unique words in Moby Dick")
# Out:
# 260819  : # of words in Moby Dick
# 19317  : # of unique words in Moby Dick

# %%
fdist1 = FreqDist(text1)
print(fdist1)
print(fdist1.most_common(50))
fdist1.plot(50, cumulative=False)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>
# [(',', 18713), ('the', 13721), ('.', 6862), ('of', 6536), ('and', 6024), ('a', 4569), ('to', 4542), (';', 4072), ('in', 3916), ('that', 2982), ("'", 2684), ('-', 2552), ('his', 2459), ('it', 2209), ('I', 2124), ('s', 1739), ('is', 1695), ('he', 1661), ('with', 1659), ('was', 1632), ('as', 1620), ('"', 1478), ('all', 1462), ('for', 1414), ('this', 1280), ('!', 1269), ('at', 1231), ('by', 1137), ('but', 1113), ('not', 1103), ('--', 1070), ('him', 1058), ('from', 1052), ('be', 1030), ('on', 1005), ('so', 918), ('whale', 906), ('one', 889), ('you', 841), ('had', 767), ('have', 760), ('there', 715), ('But', 705), ('or', 697), ('were', 680), ('now', 646), ('which', 640), ('?', 637), ('me', 627), ('like', 624)]

# %%
groucho_grammar = nltk.CFG.fromstring("""
 S -> NP VP
 PP -> P NP
 NP -> Det N | Det N PP | 'I'
 VP -> V NP | VP PP
 Det -> 'an' | 'my'
 N -> 'elephant' | 'pajamas'
 V -> 'shot'
 P -> 'in'
 """)

sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
for tree in parser.parse(sent):
    tree.draw()
    
print("Done")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     795                         binary_names=['gswin32c.exe', 'gswin64c.exe'],
#     796                         env_vars=['PATH'],
# --> 797                         verbose=False,
#     798                     )
#     799                 ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     694     return next(
# ...
